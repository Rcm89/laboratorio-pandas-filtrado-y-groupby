# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Filtrado de Datos
#
# En este laboratorio usaremos el DataFrame creado en la lección anterior resultado de la unión de los conjuntos de datos compartidos contigo.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.

# %%
# Carga el dataset de trabajo
import pandas as pd
import numpy as np

df_Netflix = pd.read_csv ("datos/netflix_merged.csv")
df_Netflix.head()
# Out:
#    Unnamed: 0            Title                  Genre           Premiere  \
# 0           0  Enter the Anime            Documentary     August 5, 2019
# 1           1      Dark Forces               Thriller    August 21, 2020
# 2           2          The App  Science fiction/Drama  December 26, 2019
# 3           3   The Open House        Horror thriller   January 19, 2018
# 4           4      Kaali Khuhi                Mystery   October 30, 2020
#
#    Runtime  IMDB Score          Language show_id   type            title  \
# 0       58         2.5  English/Japanese   s3624  Movie  Enter the Anime
# 1       81         2.6           Spanish   s2105  Movie      Dark Forces
# 2       79         2.6           Italian   s3095  Movie          The App
# 3       94         3.2           English   s5074  Movie   The Open House
# 4       90         3.4             Hindi   s1778  Movie      Kaali Khuhi
#
#                     director  \
# 0              Alex Burunova
# ...

# %% [markdown]
# #### Ejercicio 1: ¿Cuáles son todos los títulos lanzados en 2021 que son del tipo 'Movie'?

# %%
condicion_1=df_Netflix["type"] == "Movie"
condicion_2=df_Netflix["release_year"]== 2021
df_ej = df_Netflix[condicion_1 & condicion_2]
df_ej
# Out:
#      Unnamed: 0                                    Title  \
# 9             9                       Sardar Ka Grandson
# 17           17                What Happened to Mr. Cha?
# 21           21                    The Girl on the Train
# 22           22                            Thunder Force
# 24           24                             Just Say Yes
# 26           26    The Misadventures of Hedi and Cokeman
# 36           36                               Sentinelle
# 55           55                             Squared Love
# 60           60                               Geez & Ann
# 66           66                                Ghost Lab
# 74           74                      Strip Down, Rise Up
# 84           84                      Things Heard & Seen
# 94           94                            Madame Claude
# 96           96                         Outside the Wire
# 102         102                            Get the Grift
# ...

# %% [markdown]
# #### Ejercicio 2: ¿Qué títulos tienen una duración de 90 minutos? Muestra solo las columnas de título y de duración.

# %%
condicion_1=df_Netflix["duration"] == "90 min"
df_ej = df_Netflix[condicion_1]
df_ej[["title","duration"]]
# Out:
#                                        title duration
# 23                              Fatal Affair   90 min
# 123                      One-Way to Tomorrow   90 min
# 139                                 Good Sam   90 min
# 149                          The Wrong Missy   90 min
# 155                             American Son   90 min
# 173                          The After Party   90 min
# 195                                  Juanita   90 min
# 215                    Pee-wee's Big Holiday   90 min
# 252                              June & Kopi   90 min
# 326                            Recovery Boys   90 min
# 340  Crack: Cocaine, Corruption & Conspiracy   90 min
# 479                     Dick Johnson Is Dead   90 min
# 506                               Seaspiracy   90 min

# %% [markdown]
# #### Ejercicio 3: ¿Cuáles son todos los títulos del país 'India' lanzados después de 2018?

# %%
condicion_1=df_Netflix["country"] == "India"
condicion_2=df_Netflix["release_year"]>2018
df_ej = df_Netflix[condicion_1 & condicion_2]
df_ej
# Out:
#      Unnamed: 0                           Title                  Genre  \
# 4             4                     Kaali Khuhi                Mystery
# 5             5                           Drive                 Action
# 9             9              Sardar Ka Grandson                 Comedy
# 15           15                   Ghost Stories       Horror anthology
# 21           21           The Girl on the Train               Thriller
# 42           42              Mrs. Serial Killer               Thriller
# 65           65                       Firebrand                  Drama
# 81           81  Gunjan Saxena: The Kargil Girl                  Drama
# 92           92                          Guilty               Thriller
# 104         104                    House Arrest                 Comedy
# 138         138                Ginny Weds Sunny        Romantic comedy
# 151         151                       15 August           Comedy-drama
# ...

# %% [markdown]
# #### Ejercicio 4: ¿Qué títulos tienen clasificación 'TV-14' o 'R'?

# %%
condicion_1=df_Netflix["rating"] == "TV-14"
condicion_2=df_Netflix["rating"]=="R"
df_ej = df_Netflix[condicion_1 | condicion_2]
df_ej
# Out:
#      Unnamed: 0                     Title               Genre  \
# 4             4               Kaali Khuhi             Mystery
# 5             5                     Drive              Action
# 9             9        Sardar Ka Grandson              Comedy
# 11           11                   Whipped     Romantic comedy
# 16           16  The Last Thing He Wanted  Political thriller
# ..          ...                       ...                 ...
# 498         498             A Secret Love         Documentary
# 500         500            Marriage Story               Drama
# 501         501            The Ivory Game         Documentary
# 506         506                Seaspiracy         Documentary
# 508         508    Cuba and the Cameraman         Documentary
#
#                Premiere  Runtime  IMDB Score    Language show_id   type  \
# 4      October 30, 2020       90         3.4       Hindi   s1778  Movie
# 5      November 1, 2019      147         3.5       Hindi   s3335  Movie
# ...

# %% [markdown]
# #### Ejercicio 5: ¿Cuáles son los títulos dirigidos por 'Christopher Nolan' o 'Martin Scorsese'? ¿Cuántos a dirigido cada uno de los directores?

# %%
condicion_1=df_Netflix["director"] == "Christopher Nolan"
condicion_2=df_Netflix["director"] == "Martin Scorsese"
#Títulos dirgidos por Nolan y Scorsese
df_ej=df_Netflix[condicion_1 | condicion_2]
df_ej
# Out:
#      Unnamed: 0         Title        Genre           Premiere  Runtime  \
# 496         496  The Irishman  Crime drama  November 27, 2019      209
#
#      IMDB Score Language show_id   type         title         director  \
# 496         7.8  English   s3228  Movie  The Irishman  Martin Scorsese
#
#                                                   cast        country  \
# 496  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...  United States
#
#             date_added  release_year rating duration listed_in  \
# 496  November 27, 2019          2019      R  209 min    Dramas
#
#                                            description
# 496  Hit man Frank Sheeran looks back at the secret...

# %%
#Títulos de Christopher Nolan
df_Netflix[condicion_1].shape[0]
# Out:
# 0

# %%
#Títulos de Martin Scorsese
df_Netflix[condicion_2].shape[0]
# Out:
# 1

# %% [markdown]
# #### Ejercicio 6: ¿Qué títulos pertenecen a los países 'United States', 'United Kingdom' o 'Canada'? Dentro de estos países, ¿cuántas películas tienen más de un lenguaje?

# %%
condicion_1=df_Netflix["country"] == "United States"
condicion_2=df_Netflix["country"] == "United Kingdom"
condicion_3=df_Netflix["country"] == "Canada"
df_ej=df_Netflix[condicion_1 | condicion_2 | condicion_3]
df_ej
#df_ej[condicion_paises]
# Out:
#      Unnamed: 0                            Title                    Genre  \
# 7             7  The Last Days of American Crime      Heist film/Thriller
# 8             8                          Paradox  Musical/Western/Fantasy
# 13           13                            Mercy                 Thriller
# 16           16         The Last Thing He Wanted       Political thriller
# 18           18                       Death Note          Horror thriller
# ..          ...                              ...                      ...
# 504         504                   Rising Phoenix              Documentary
# 506         506                       Seaspiracy              Documentary
# 508         508           Cuba and the Cameraman              Documentary
# 509         509           Dancing with the Birds              Documentary
# 511         511          Springsteen on Broadway             One-man show
#
#               Premiere  Runtime  IMDB Score Language show_id   type  \
# ...

# %%
df_varios_idiomas = df_ej[df_ej["Language"].str.contains('/')]
df_varios_idiomas["Language"].count()
# Out:
# np.int64(10)

# %%
df_ej["Language"].str.contains('/').sum()
# Out:
# np.int64(10)

# %% [markdown]
# Lo he sacado de las dos maneras diferentes para practicar diferentes métodos y la diferencia entre serie y dataFrame

# %% [markdown]
# #### Ejercicio 7: ¿Qué títulos fueron lanzados entre 2015 y 2020, inclusive?

# %%
condicion=df_Netflix['release_year'].between(2015, 2020)
df_Netflix[condicion]
# Out:
#      Unnamed: 0                                        Title  \
# 0             0                              Enter the Anime
# 1             1                                  Dark Forces
# 2             2                                      The App
# 3             3                               The Open House
# 4             4                                  Kaali Khuhi
# ..          ...                                          ...
# 508         508                       Cuba and the Cameraman
# 509         509                       Dancing with the Birds
# 510         510  Winter on Fire: Ukraine's Fight for Freedom
# 511         511                      Springsteen on Broadway
# 512         512     David Attenborough: A Life on Our Planet
#
#                      Genre           Premiere  Runtime  IMDB Score  \
# 0              Documentary     August 5, 2019       58         2.5
# 1                 Thriller    August 21, 2020       81         2.6
# ...

# %% [markdown]
# #### Ejercicio 8: ¿Cuáles son los títulos cuya puntuación en IMDb está entre 6.5 y 8.0 y que no sepamos cual es su duración?

# %%
condicion_1=df_Netflix['IMDB Score'].between(6.5, 8.0)
condicion_2=df_Netflix['duration'].isnull()
df_ej=df_Netflix[condicion_1 & condicion_2]
df_ej
# Out:
#      Unnamed: 0                               Title            Genre  \
# 295         295                    All Together Now            Drama
# 299         299                          Chopsticks           Comedy
# 303         303                       Gerald's Game  Horror thriller
# 304         304                           His House         Thriller
# 308         308                             Monster            Drama
# ..          ...                                 ...              ...
# 487         487                    Tell Me Who I Am      Documentary
# 488         488                   The Bleeding Edge      Documentary
# 489         489                  The Social Dilemma      Documentary
# 491         491         What Happened, Miss Simone?      Documentary
# 494         494  Crip Camp: A Disability Revolution      Documentary
#
#                Premiere  Runtime  IMDB Score Language show_id   type  \
# ...

# %% [markdown]
# #### Ejercicio 9: ¿Cuáles son las películas cuya duración de 90 y 150 minutos?

# %%
condicion_1= df_Netflix['duration'] == "90 min"
condicion_2= df_Netflix['duration'] == "150 min"
condicion_3 = df_Netflix['type'] == 'Movie'
df_ej=df_Netflix[condicion_1 | condicion_2 & condicion_3]
df_ej
# Out:
#      Unnamed: 0                                    Title  \
# 23           23                             Fatal Affair
# 123         123                      One-Way to Tomorrow
# 139         139                                 Good Sam
# 149         149                          The Wrong Missy
# 155         155                             American Son
# 173         173                          The After Party
# 195         195                                  Juanita
# 215         215                    Pee-wee's Big Holiday
# 252         252                              June & Kopi
# 326         326                            Recovery Boys
# 340         340  Crack: Cocaine, Corruption & Conspiracy
# 456         456                           Raat Akeli Hai
# 479         479                     Dick Johnson Is Dead
# 485         485                                     Ludo
# 506         506                               Seaspiracy
#
# ...

# %% [markdown]
# #### Ejercicio 10: ¿Cuáles son los títulos que contienen la palabra 'Love' en su título y que sean de tipo TV Show?

# %%
condicion_1 = df_Netflix['Title'].str.contains('Love')
condicion_2 = df_Netflix['type'] == 'TV Show'
df_ej = df_Netflix[condicion_1 & condicion_2]
df_ej
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Genre, Premiere, Runtime, IMDB Score, Language, show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### Ejercicio 11: ¿Cuáles son los títulos en los que el director tiene el apellido 'Johnson'?

# %%
condicion_1 = df_Netflix['director'].str.contains('Johnson', case=False, na=False)

df_ej = df_Netflix[condicion_1]
df_ej
# Out:
#      Unnamed: 0                 Title            Genre           Premiere  \
# 122         122      Love, Guaranteed  Romantic comedy  September 3, 2020
# 195         195               Juanita            Drama      March 8, 2019
# 244         244      Alex Strangelove  Romantic comedy       June 8, 2018
# 479         479  Dick Johnson Is Dead      Documentary    October 2, 2020
#
#      Runtime  IMDB Score Language show_id   type                 title  \
# 122       91         5.6  English   s2053  Movie      Love, Guaranteed
# 195       90         6.0  English   s4034  Movie               Juanita
# 244       99         6.3  English   s4834  Movie      Alex Strangelove
# 479       90         7.5  English      s1  Movie  Dick Johnson Is Dead
#
#                 director                                               cast  \
# 122  Mark Steven Johnson  Rachael Leigh Cook, Damon Wayans Jr., Heather ...
# 195        Clark Johnson  Alfre Woodard, Adam Beach, LaTanya Richardson ...
# ...

# %% [markdown]
# #### Ejercicio 12: ¿Tenemos algún documental ('Documentaries') de Mike Tyson?

# %%
condicion_1 = df_Netflix['listed_in'].str.contains('Documentaries', case=False, na=False)
condicion_2 = df_Netflix['cast'].str.contains('Mike Tyson', case=False, na=False)
df_ej = df_Netflix[condicion_1 & condicion_2]
df_ej
# Out:
#   Cell In[126], line 3
#     df_ej = df_Netflix[condicion_1 & condicion_2](df_ej
#                                                        ^
# SyntaxError: incomplete input

# %% [markdown]
# #### Ejercicio 13: Selecciona solo las columnas 'title', 'country' y 'release_year' del dataset.

# %%
df_ej=df_Netflix[['title', 'country', 'release_year']]
df_ej
# Out:
#                                            title  \
# 0                                Enter the Anime
# 1                                    Dark Forces
# 2                                        The App
# 3                                 The Open House
# 4                                    Kaali Khuhi
# ..                                           ...
# 508                       Cuba and the Cameraman
# 509                       Dancing with the Birds
# 510  Winter on Fire: Ukraine's Fight for Freedom
# 511                      Springsteen on Broadway
# 512     David Attenborough: A Life on Our Planet
#
#                                     country  release_year
# 0                      United States, Japan          2019
# 1                                    Mexico          2020
# 2                                     Italy          2019
# 3                     Canada, United States          2018
# 4                                     India          2020
# ...

# %% [markdown]
# #### Ejercicio 14: Filtra las columnas que contienen la palabra 'date'.

# %%
columnas_date = df_Netflix.filter(like='date', axis=1)
columnas_date
# Out:
#             date_added
# 0       August 5, 2019
# 1      August 21, 2020
# 2    December 26, 2019
# 3     January 19, 2018
# 4     October 30, 2020
# ..                 ...
# 508  November 24, 2017
# 509   October 23, 2019
# 510    October 9, 2015
# 511  December 16, 2018
# 512    October 4, 2020
#
# [513 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 15: Usando `query()`, filtra todos los títulos del país 'France' con una duración de 80 minutos.

# %%
df_ej = df_Netflix.query("country == 'France' and duration == '80 min'")
df_ej
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Genre, Premiere, Runtime, IMDB Score, Language, show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### Ejercicio 16: Filtra los títulos que son películas ('Movie') y fueron lanzados antes de 2010.

# %% [markdown]
# #### Ejercicio 17: Encuentra los 10 títulos con las puntuaciones más altas en IMDb.

# %%
condicion_1 = df_Netflix['type'] == 'Movie'
condicion_2 = df_Netflix['release_year'] < 2010
df_ej = df_Netflix[condicion_1 & condicion_2]
df_ej
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Genre, Premiere, Runtime, IMDB Score, Language, show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### Ejercicio 18: Encuentra los 5 títulos con las puntuaciones más bajas en IMDb.

# %% [markdown]
# #### Ejercicio 19: Filtra todos los títulos que no tienen un director asignado (valores nulos en la columna 'director').

# %% [markdown]
# #### Ejercicio 20: Filtra todos los títulos que tienen información completa en las columnas 'title', 'country' y 'IMDB Score'.

# %% [markdown]
# #### Ejercicio 21: Identifica si hay títulos duplicados en la columna 'title'.
